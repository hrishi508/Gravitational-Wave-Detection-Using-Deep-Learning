# %%
################################
########### IMPORTS ############
################################

# %%
from pycbc import distributions
from pycbc.waveform import get_td_waveform, td_approximants
from pycbc.detector import Detector
import matplotlib.pyplot as plt
import numpy as np
import gwpy
import pylab
from tqdm.notebook import tqdm
from gwpy.timeseries import TimeSeries
import pandas as pd
import os
import csv
import pycbc.noise
import pycbc.psd
from pycbc.filter import matched_filter

# %%
###############################################################
########### Plot BBH Strain Data Generated by Code ############
###############################################################

# %%
for i in tqdm(range(100)):
    merged_bbh = TimeSeries.read("/home/hrishi/SOP/Gravitational Wave Detection Using Deep Learning/raw_data_files/merged_bbh_noise_signal/merged_noise_signal_"+str(i)+".txt")
    plt.figure(facecolor='white')
    plt.plot(merged_bbh)
    plt.savefig('/home/hrishi/SOP/Gravitational Wave Detection Using Deep Learning/plots/merged_bbh/fig_'+str(i)+'.png')
    plt.close()

# %%
#################################################################################
########### Plot BBH Strain Data Obtained from LIGO and Preprocessed ############
#################################################################################

# %%
bbh_events = os.listdir('/home/hrishi/SOP/Gravitational Wave Detection Using Deep Learning/LIGO Detector Data/BBH mergers/Processed signals/')

for i in tqdm(range(len(bbh_events))):
    merged_bbh = TimeSeries.read("/home/hrishi/SOP/Gravitational Wave Detection Using Deep Learning/LIGO Detector Data/BBH mergers/Processed signals/"+bbh_events[i])
    plt.figure(facecolor='white')
    plt.plot(merged_bbh)
    plt.title(bbh_events[i][:-4])
    plt.savefig('/home/hrishi/SOP/Gravitational Wave Detection Using Deep Learning/plots/LIGO_bbh/fig_'+str(i)+'.png')
    plt.close()
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]

# %%
#############################################################################
########### Plot Rescaled(0.2) BBH Strain Data Generated by Code ############
#############################################################################

# %%
for i in tqdm(range(100)):
    merged_bbh = TimeSeries.read("/home/hrishi/SOP/Gravitational Wave Detection Using Deep Learning/models/debugging/1D-CNN Binary Classification/Signal_HIDDEN_in_strain_data/Signal_NOT_WHITENED/Test 6/data/merged/bbh_merged_noise_signal_"+str(i)+".txt")
    plt.figure(facecolor='white')
    plt.plot(merged_bbh)
    plt.savefig('/home/hrishi/SOP/Gravitational Wave Detection Using Deep Learning/plots/rescaled(0.2)_merged_bbh/fig_'+str(i)+'.png')
    plt.close()

# %%
#############################################################################
########### Plot Rescaled(0.1) BBH Strain Data Generated by Code ############
#############################################################################

# %%
for i in tqdm(range(100)):
    merged_bbh = TimeSeries.read("/home/hrishi/SOP/Gravitational Wave Detection Using Deep Learning/models/debugging/1D-CNN Binary Classification/Signal_HIDDEN_in_strain_data/Signal_NOT_WHITENED/Test 6/data/merged/bbh_merged_noise_signal_"+str(i)+".txt")
    plt.figure(facecolor='white')
    plt.plot(merged_bbh)
    plt.savefig('/home/hrishi/SOP/Gravitational Wave Detection Using Deep Learning/plots/rescaled(0.1)_merged_bbh/fig_'+str(i)+'.png')
    plt.close()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
